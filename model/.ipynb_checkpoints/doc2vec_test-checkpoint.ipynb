# %%
# !pip freeze
# !pip install gensim
import nltk
nltk.download('punkt')
import pandas as pd
import re
from nltk.tokenize import word_tokenize, sent_tokenize
from gensim.models import Word2Vec
from sklearn.metrics.pairwise import  cosine_similarity
df_train = pd.read_execl("../dataset/ex_merged.xlsx")
#df_train = pd.read_csv("https://raw.githubusercontent.com/SNMHZ/Drug_Recommendation/master/dataset/lem_train.csv", parse_dates=["date"], infer_datetime_format=True)
df_test = pd.read_csv("https://raw.githubusercontent.com/SNMHZ/Drug_Recommendation/master/dataset/lem_test.csv", parse_dates=["date"], infer_datetime_format=True)

print(type(df_train['review']))

#df_train['tokenize_review'] = word_tokenize(df_train['review'])

print(df_train.isnull().values.any())
print(df_test.isnull().values.any())

print(len(df_train))
print(len(df_test))

df_train = df_train.dropna(how='any')
df_test = df_test.dropna(how='any')

print(df_train.isnull().values.any())
print(df_test.isnull().values.any())

print(len(df_train))
print(len(df_test))
print(df_train['review'][0])

#df_train['new'] = df_train['review'].str.cat(df_train['condition'], sep=' ')
#df_train['new'] = df_train['new'].str.lower()

# %%
from gensim.models.doc2vec import Doc2Vec, TaggedDocument
import pandas, nltk
from nltk.tokenize import RegexpTokenizer

#df_all = pd.concat([df_train, df_test])

def nltk_tokenizer(words):
  return RegexpTokenizer(r'\n+').tokenize(words.lower())
print(df_all['condition2'])
df_train['tokenized'] = [word_tokenize(sentence) for sentence in df_train['review']]
print(df_train.head())
doc_df = df_train[['condition2', 'tokenized']].values.tolist()
tagged_data = [TaggedDocument(words=_d, tags=[uid]) for uid, _d in doc_df]
max_epochs = 10

model = Doc2Vec(
    window=10,
    vector_size=150,
    alpha=0.025, 
    min_alpha=0.025,
    min_count=2,
    dm =1,
    negative = 5,
    seed = 9999)

model.build_vocab(tagged_data)

print(tagged_data[:5])
# Out:
# 0        Left Ventricular Dysfunction
# 1                                ADHD
# 2                       Birth Control
# 3                       Birth Control
# 4                   Opiate Dependence
#                      ...
# 53195       Breast Cancer, Prevention
# 53196                         Anxiety
# 53197                   Birth Control
# 53198                            Pain
# 53199                        Sciatica
# Name: condition, Length: 212535, dtype: object
#    Unnamed: 0  level_0  uniqueID                  drugName  \
# 0           0        0    206461                 Valsartan
# 1           1        1     95260                Guanfacine
# 2           2        2     92703                    Lybrel
# 3           3        3    138000                Ortho Evra
# 4           4        4     35696  Buprenorphine / naloxone
#
#                       condition  \
# 0  Left Ventricular Dysfunction
# 1                          ADHD
# 2                 Birth Control
# 3                 Birth Control
# 4             Opiate Dependence
#
#                                               review  rating       date  \
# 0  side effect take combination bystolic mg fish oil       9 2012-05-20
# 1  son halfway fourth week intuniv become concern...       8 2010-04-27
# 2  use take another oral contraceptive pill cycle...       5 2009-12-14
# 3  first time use form birth control glad go patc...       8 2015-11-03
# 4  suboxone completely turn life around feel heal...       9 2016-11-27
#
#    usefulCount                                                new  \
# 0           27  side effect take combination bystolic mg fish ...
# 1          192  son halfway fourth week intuniv become concern...
# 2           17  use take another oral contraceptive pill cycle...
# 3           10  first time use form birth control glad go patc...
# 4           37  suboxone completely turn life around feel heal...
#
#                                            tokenized
# 0  [side, effect, take, combination, bystolic, mg...
# 1  [son, halfway, fourth, week, intuniv, become, ...
# 2  [use, take, another, oral, contraceptive, pill...
# 3  [first, time, use, form, birth, control, glad,...
# 4  [suboxone, completely, turn, life, around, fee...
# [TaggedDocument(words=['side', 'effect', 'take', 'combination', 'bystolic', 'mg', 'fish', 'oil', 'left', 'ventricular', 'dysfunction'], tags=['Valsartan']), TaggedDocument(words=['son', 'halfway', 'fourth', 'week', 'intuniv', 'become', 'concerned', 'begin', 'last', 'week', 'start', 'take', 'high', 'dose', 'two', 'day', 'could', 'hardly', 'get', 'bed', 'cranky', 'slept', 'nearly', 'hour', 'drive', 'home', 'school', 'vacation', 'unusual', 'call', 'doctor', 'monday', 'morning', 'say', 'stick', 'day', 'see', 'school', 'get', 'morning', 'last', 'two', 'day', 'problem', 'free', 'much', 'agreeable', 'ever', 'less', 'emotional', 'good', 'thing', 'less', 'cranky', 'remember', 'thing', 'overall', 'behavior', 'well', 'try', 'many', 'different', 'medication', 'far', 'effective', 'adhd'], tags=['Guanfacine']), TaggedDocument(words=['use', 'take', 'another', 'oral', 'contraceptive', 'pill', 'cycle', 'happy', 'light', 'period', 'max', 'day', 'side', 'effect', 'contain', 'hormone', 'gestodene', 'available', 'u', 'switch', 'lybrel', 'ingredient', 'similar', 'pill', 'end', 'start', 'lybrel', 'immediately', 'first', 'day', 'period', 'instruction', 'say', 'period', 'last', 'two', 'week', 'take', 'second', 'pack', 'two', 'week', 'third', 'pack', 'thing', 'get', 'even', 'bad', 'third', 'period', 'last', 'two', 'week', 'end', 'third', 'week', 'still', 'daily', 'brown', 'discharge', 'positive', 'side', 'side', 'effect', 'idea', 'period', 'free', 'tempt', 'ala', 'birth', 'control'], tags=['Lybrel']), TaggedDocument(words=['first', 'time', 'use', 'form', 'birth', 'control', 'glad', 'go', 'patch', 'month', 'first', 'decrease', 'libido', 'subside', 'downside', 'make', 'period', 'longer', 'day', 'exact', 'use', 'period', 'day', 'max', 'also', 'make', 'cramp', 'intense', 'first', 'two', 'day', 'period', 'never', 'cramp', 'use', 'birth', 'control', 'happy', 'patch', 'birth', 'control'], tags=['Ortho Evra']), TaggedDocument(words=['suboxone', 'completely', 'turn', 'life', 'around', 'feel', 'healthier', 'excel', 'job', 'always', 'money', 'pocket', 'saving', 'account', 'none', 'suboxone', 'spent', 'year', 'abuse', 'oxycontin', 'paycheck', 'already', 'spent', 'time', 'get', 'start', 'resort', 'scheme', 'steal', 'fund', 'addiction', 'history', 'ready', 'stop', 'good', 'chance', 'suboxone', 'put', 'path', 'great', 'life', 'found', 'sideeffects', 'minimal', 'compare', 'oxycontin', 'actually', 'sleep', 'well', 'slight', 'constipation', 'truly', 'amaze', 'cost', 'pale', 'comparison', 'spent', 'oxycontin', 'opiate', 'dependence'], tags=['Buprenorphine / naloxone'])]

# %%
print(tagged_data[:5])

for epoch in range(max_epochs):
    print('iteration {0}'.format(epoch))
    model.train(tagged_data,
                total_examples=model.corpus_count,
                epochs=model.epochs)
    print("training loss = ", model.get_latest_training_loss())
    # decrease the learning rate
    model.alpha -= 0.002
    # fix the learning rate, no decay
    model.min_alpha = model.alpha
doc_list = 'increase b number plus alot energy lose weight'.split(' ')

inferred_vector = model.infer_vector(doc_list)
return_docs = model.docvecs.most_similar(positive=[inferred_vector], topn=5)
print(return_docs)
for rd in return_docs:
  for des in df_train[df_train['condition2'] == rd[0]]['review']:
    print(rd[0], rd[1], des)
print("done")
# Out:
# [TaggedDocument(words=['side', 'effect', 'take', 'combination', 'bystolic', 'mg', 'fish', 'oil', 'left', 'ventricular', 'dysfunction'], tags=['Valsartan']), TaggedDocument(words=['son', 'halfway', 'fourth', 'week', 'intuniv', 'become', 'concerned', 'begin', 'last', 'week', 'start', 'take', 'high', 'dose', 'two', 'day', 'could', 'hardly', 'get', 'bed', 'cranky', 'slept', 'nearly', 'hour', 'drive', 'home', 'school', 'vacation', 'unusual', 'call', 'doctor', 'monday', 'morning', 'say', 'stick', 'day', 'see', 'school', 'get', 'morning', 'last', 'two', 'day', 'problem', 'free', 'much', 'agreeable', 'ever', 'less', 'emotional', 'good', 'thing', 'less', 'cranky', 'remember', 'thing', 'overall', 'behavior', 'well', 'try', 'many', 'different', 'medication', 'far', 'effective', 'adhd'], tags=['Guanfacine']), TaggedDocument(words=['use', 'take', 'another', 'oral', 'contraceptive', 'pill', 'cycle', 'happy', 'light', 'period', 'max', 'day', 'side', 'effect', 'contain', 'hormone', 'gestodene', 'available', 'u', 'switch', 'lybrel', 'ingredient', 'similar', 'pill', 'end', 'start', 'lybrel', 'immediately', 'first', 'day', 'period', 'instruction', 'say', 'period', 'last', 'two', 'week', 'take', 'second', 'pack', 'two', 'week', 'third', 'pack', 'thing', 'get', 'even', 'bad', 'third', 'period', 'last', 'two', 'week', 'end', 'third', 'week', 'still', 'daily', 'brown', 'discharge', 'positive', 'side', 'side', 'effect', 'idea', 'period', 'free', 'tempt', 'ala', 'birth', 'control'], tags=['Lybrel']), TaggedDocument(words=['first', 'time', 'use', 'form', 'birth', 'control', 'glad', 'go', 'patch', 'month', 'first', 'decrease', 'libido', 'subside', 'downside', 'make', 'period', 'longer', 'day', 'exact', 'use', 'period', 'day', 'max', 'also', 'make', 'cramp', 'intense', 'first', 'two', 'day', 'period', 'never', 'cramp', 'use', 'birth', 'control', 'happy', 'patch', 'birth', 'control'], tags=['Ortho Evra']), TaggedDocument(words=['suboxone', 'completely', 'turn', 'life', 'around', 'feel', 'healthier', 'excel', 'job', 'always', 'money', 'pocket', 'saving', 'account', 'none', 'suboxone', 'spent', 'year', 'abuse', 'oxycontin', 'paycheck', 'already', 'spent', 'time', 'get', 'start', 'resort', 'scheme', 'steal', 'fund', 'addiction', 'history', 'ready', 'stop', 'good', 'chance', 'suboxone', 'put', 'path', 'great', 'life', 'found', 'sideeffects', 'minimal', 'compare', 'oxycontin', 'actually', 'sleep', 'well', 'slight', 'constipation', 'truly', 'amaze', 'cost', 'pale', 'comparison', 'spent', 'oxycontin', 'opiate', 'dependence'], tags=['Buprenorphine / naloxone'])]
# iteration 0
# iteration 1
# iteration 2
# iteration 3
# iteration 4
# iteration 5

# %%
while True:
    test = input("what ? = ").split(' ')
    inferred_vector = model.infer_vector(test)
    return_docs = model.docvecs.most_similar(positive=[inferred_vector], topn=5)
    print(return_docs)
    for rd in return_docs:
      for des in df_train[df_train['condition2'] == rd[0]]['review']:
        print(rd[0], rd[1], des)
    print("done")
